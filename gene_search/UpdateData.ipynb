# %%
import os, django

# check or modify environment variable, like "PATH" .etc
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'gene_search.settings')
# check this https://stackoverflow.com/questions/61926359/django-synchronousonlyoperation-you-cannot-call-this-from-an-async-context-u
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

# %% [markdown]
# ## Details are in https://docs.djangoproject.com/en/5.1/topics/db/queries/

# %%
from search.models import BigTableV2

# %% [markdown]
# ### get all rows

# %%
len(BigTableV2.objects.all())
# Out:
# 65338

# %% [markdown]
# ### find certain row

# %%
b = BigTableV2.objects.get(gene_name="aap-1")
b
# Out:
# <BigTableV2:
#             id:65340
#             gene_id:WBGene00000001
#             status:Live
#             sequence_name:Y110A7A.10
#             gene_name:aap-1
#             other_name:CELE_Y110A7A.10
#             transcript_name:Y110A7A.10.1
#             type:coding_transcript
#         >

# %% [markdown]
# ### filter by some columns value

# %%
b = BigTableV2.objects.filter(gene_name="aat-3")
b
# Out:
# <QuerySet [<BigTableV2:
#             id:65343
#             gene_id:WBGene00000004
#             status:Live
#             sequence_name:F52H2.2
#             gene_name:aat-3
#             other_name:CELE_F52H2.2
#             transcript_name:F52H2.2a.1
#             type:coding_transcript
#         >, <BigTableV2:
#             id:65344
#             gene_id:WBGene00000004
#             status:Live
#             sequence_name:F52H2.2
#             gene_name:aat-3
#             other_name:CELE_F52H2.2
#             transcript_name:F52H2.2b.1
#             type:coding_transcript
#         >]>

# %% [markdown]
# ### delete certain row

# %%
b_list = BigTableV2.objects.all()
b_list.delete() # delete all rows :)
# Out:
# (69442, {'search.BigTableV2': 69442})

# %% [markdown]
# ### Insert rows into database (inefficiency due to one by one)
#
# one can see that it took 5m 24.5s to insert 65338 rows

# %%
path = "big_table_v2.csv"

with open(path, 'r') as file:
    for x in file.readlines()[1:]: # skip first row
        """
            Gene_ID       , Status, Sequence_Name, Gene_Name, Other_Name     , Transcript_Name, Type
            WBGene00000001, Live  , Y110A7A.10   , aap-1    , CELE_Y110A7A.10, Y110A7A.10.1   , coding_transcript

            ......
        """
        gene_id,status,sequence_name,gene_name,other_name,transcript_name,type = x.strip("\n").split(",") # strip off "\n", then split by ","
        b = BigTableV2(
            gene_id = gene_id,
            status = status,
            sequence_name = sequence_name,
            gene_name = gene_name,
            other_name = other_name,
            transcript_name = transcript_name,
            type = type,
        )  
        b.save() # can use "BigTableV2.objects.create(...)" instead
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 21
#      11 gene_id,status,sequence_name,gene_name,other_name,transcript_name,type = x.strip("\n").split(",") # strip off "\n", then split by ","
#      12 b = BigTableV2(
#      13     gene_id = gene_id,
#      14     status = status,
#    (...)
#      19     type = type,
#      20 )
# ---> 21 b.save() # can use "BigTableV2.objects.create(...)" instead
#
# File c:\Users\jimmy\miniconda3\envs\pc\Lib\site-packages\django\db\models\base.py:822, in Model.save(self, force_insert, force_update, using, update_fields)
#     819     if loaded_fields:
#     820         update_fields = frozenset(loaded_fields)
# --> 822 self.save_base(
#     823     using=using,
#     824     force_insert=force_insert,
#     825     force_update=force_update,
#     826     update_fields=update_fields,
#     827 )
#
# File c:\Users\jimmy\miniconda3\envs\pc\Lib\site-packages\django\db\models\base.py:909, in Model.save_base(self, raw, force_insert, force_update, using, update_fields)
#     905         force_insert = self._validate_force_insert(force_insert)
#     906         parent_inserted = self._save_parents(
#     907             cls, using, update_fields, force_insert
#     908         )
# --> 909     updated = self._save_table(
#     910         raw,
#     911         cls,
#     912         force_insert or parent_inserted,
#     913         force_update,
#     914         using,
#     915         update_fields,
#     916     )
#     917 # Store the database on which the object was saved
#     918 self._state.db = using
#
# File c:\Users\jimmy\miniconda3\envs\pc\Lib\site-packages\django\db\models\base.py:1071, in Model._save_table(self, raw, cls, force_insert, force_update, using, update_fields)
#    1065 fields = [
#    1066     f
#    1067     for f in meta.local_concrete_fields
#    1068     if not f.generated and (pk_set or f is not meta.auto_field)
#    1069 ]
#    1070 returning_fields = meta.db_returning_fields
# -> 1071 results = self._do_insert(
#    1072     cls._base_manager, using, fields, returning_fields, raw
#    1073 )
#    1074 if results:
#    1075     for value, field in zip(results[0], returning_fields):
#
# File c:\Users\jimmy\miniconda3\envs\pc\Lib\site-packages\django\db\models\base.py:1112, in Model._do_insert(self, manager, using, fields, returning_fields, raw)
#    1107 def _do_insert(self, manager, using, fields, returning_fields, raw):
#    1108     """
#    1109     Do an INSERT. If returning_fields is defined then this method should
#    1110     return the newly created data for the model.
#    1111     """
# -> 1112     return manager._insert(
#    1113         [self],
#    1114         fields=fields,
#    1115         returning_fields=returning_fields,
#    1116         using=using,
#    1117         raw=raw,
#    1118     )
#
# File c:\Users\jimmy\miniconda3\envs\pc\Lib\site-packages\django\db\models\manager.py:87, in BaseManager._get_queryset_methods.<locals>.create_method.<locals>.manager_method(self, *args, **kwargs)
#      85 @wraps(method)
#      86 def manager_method(self, *args, **kwargs):
# ---> 87     return getattr(self.get_queryset(), name)(*args, **kwargs)
#
# File c:\Users\jimmy\miniconda3\envs\pc\Lib\site-packages\django\db\models\query.py:1847, in QuerySet._insert(self, objs, fields, returning_fields, raw, using, on_conflict, update_fields, unique_fields)
#    1840 query = sql.InsertQuery(
#    1841     self.model,
#    1842     on_conflict=on_conflict,
#    1843     update_fields=update_fields,
#    1844     unique_fields=unique_fields,
#    1845 )
#    1846 query.insert_values(fields, objs, raw=raw)
# -> 1847 return query.get_compiler(using=using).execute_sql(returning_fields)
#
# File c:\Users\jimmy\miniconda3\envs\pc\Lib\site-packages\django\db\models\sql\compiler.py:1835, in SQLInsertCompiler.execute_sql(self, returning_fields)
#    1832 elif self.connection.features.can_return_columns_from_insert:
#    1833     assert len(self.query.objs) == 1
#    1834     rows = [
# -> 1835         self.connection.ops.fetch_returned_insert_columns(
#    1836             cursor,
#    1837             self.returning_params,
#    1838         )
#    1839     ]
#    1840     cols = [field.get_col(opts.db_table) for field in self.returning_fields]
#    1841 else:
#
# File c:\Users\jimmy\miniconda3\envs\pc\Lib\site-packages\django\db\backends\base\operations.py:216, in BaseDatabaseOperations.fetch_returned_insert_columns(self, cursor, returning_params)
#     211 def fetch_returned_insert_columns(self, cursor, returning_params):
#     212     """
#     213     Given a cursor object that has just performed an INSERT...RETURNING
#     214     statement into a table, return the newly created data.
#     215     """
# --> 216     return cursor.fetchone()
#
# File c:\Users\jimmy\miniconda3\envs\pc\Lib\site-packages\django\db\utils.py:98, in DatabaseErrorWrapper.__call__.<locals>.inner(*args, **kwargs)
#      96 def inner(*args, **kwargs):
#      97     with self:
# ---> 98         return func(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Insert rows into database (Efficiency)
#
# checkout https://docs.djangoproject.com/en/5.1/ref/models/querysets/#bulk-create
#
# one can see that it only take 2s

# %%
from search.models import BigTableV2
path = "big_table_v2.csv"

data_list = []
with open(path, 'r') as file:
    for x in file.readlines()[1:]: # skip first row
        """
            Gene_ID       , Status, Sequence_Name, Gene_Name, Other_Name     , Transcript_Name, Type
            WBGene00000001, Live  , Y110A7A.10   , aap-1    , CELE_Y110A7A.10, Y110A7A.10.1   , coding_transcript

            ......
        """
        
        gene_id,status,sequence_name,gene_name,other_name,transcript_name,type = x.strip("\n").split(",") # strip off "\n", then split by ","
        data_list.append(
            BigTableV2(
                gene_id = gene_id,
                status = status,
                sequence_name = sequence_name,
                gene_name = gene_name,
                other_name = other_name,
                transcript_name = transcript_name,
                type = type,
            )    
        )
        
# Insert many many data in only one query (or less queries, if you set a batch size)
BigTableV2.objects.bulk_create(data_list, batch_size=10000)
# Out:
# [<BigTableV2:
#              id:200120
#              gene_id:WBGene00000001
#              status:Live
#              sequence_name:Y110A7A.10
#              gene_name:aap-1
#              other_name:CELE_Y110A7A.10
#              transcript_name:Y110A7A.10.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200121
#              gene_id:WBGene00000002
#              status:Live
#              sequence_name:F27C8.1
#              gene_name:aat-1
#              other_name:CELE_F27C8.1
#              transcript_name:F27C8.1.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200122
#              gene_id:WBGene00000003
#              status:Live
#              sequence_name:F07C3.7
#              gene_name:aat-2
#              other_name:CELE_F07C3.7
#              transcript_name:F07C3.7.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200123
#              gene_id:WBGene00000004
#              status:Live
#              sequence_name:F52H2.2
#              gene_name:aat-3
#              other_name:CELE_F52H2.2
#              transcript_name:F52H2.2a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200124
#              gene_id:WBGene00000004
#              status:Live
#              sequence_name:F52H2.2
#              gene_name:aat-3
#              other_name:CELE_F52H2.2
#              transcript_name:F52H2.2b.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200125
#              gene_id:WBGene00000005
#              status:Live
#              sequence_name:T13A10.10
#              gene_name:aat-4
#              other_name:CELE_T13A10.10
#              transcript_name:T13A10.10a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200126
#              gene_id:WBGene00000005
#              status:Live
#              sequence_name:T13A10.10
#              gene_name:aat-4
#              other_name:CELE_T13A10.10
#              transcript_name:T13A10.10b
#              type:nc_primary_transcript
#          >,
#  <BigTableV2:
#              id:200127
#              gene_id:WBGene00000006
#              status:Live
#              sequence_name:C55C2.5
#              gene_name:aat-5
#              other_name:CELE_C55C2.5
#              transcript_name:C55C2.5a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200128
#              gene_id:WBGene00000006
#              status:Live
#              sequence_name:C55C2.5
#              gene_name:aat-5
#              other_name:CELE_C55C2.5
#              transcript_name:C55C2.5b
#              type:nc_primary_transcript
#          >,
#  <BigTableV2:
#              id:200129
#              gene_id:WBGene00000006
#              status:Live
#              sequence_name:C55C2.5
#              gene_name:aat-5
#              other_name:CELE_C55C2.5
#              transcript_name:C55C2.5c
#              type:nc_primary_transcript
#          >,
#  <BigTableV2:
#              id:200130
#              gene_id:WBGene00000006
#              status:Live
#              sequence_name:C55C2.5
#              gene_name:aat-5
#              other_name:CELE_C55C2.5
#              transcript_name:C55C2.5d
#              type:nc_primary_transcript
#          >,
#  <BigTableV2:
#              id:200131
#              gene_id:WBGene00000007
#              status:Live
#              sequence_name:T11F9.4
#              gene_name:aat-6
#              other_name:CELE_T11F9.4
#              transcript_name:T11F9.4a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200132
#              gene_id:WBGene00000007
#              status:Live
#              sequence_name:T11F9.4
#              gene_name:aat-6
#              other_name:CELE_T11F9.4
#              transcript_name:T11F9.4b.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200133
#              gene_id:WBGene00000008
#              status:Live
#              sequence_name:F54D12.3
#              gene_name:aat-7
#              other_name:F54D12.f
#              transcript_name:F54D12.3.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200134
#              gene_id:WBGene00000009
#              status:Live
#              sequence_name:F28F9.4
#              gene_name:aat-8
#              other_name:CELE_F28F9.4
#              transcript_name:F28F9.4.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200135
#              gene_id:WBGene00000010
#              status:Live
#              sequence_name:Y53H1C.1
#              gene_name:aat-9
#              other_name:CELE_Y53H1C.1
#              transcript_name:Y53H1C.1a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200136
#              gene_id:WBGene00000010
#              status:Live
#              sequence_name:Y53H1C.1
#              gene_name:aat-9
#              other_name:CELE_Y53H1C.1
#              transcript_name:Y53H1C.1b.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200137
#              gene_id:WBGene00000011
#              status:Live
#              sequence_name:
#              gene_name:abc-1
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:200138
#              gene_id:WBGene00000012
#              status:Live
#              sequence_name:C50F2.9
#              gene_name:abf-1
#              other_name:CELE_C50F2.9
#              transcript_name:C50F2.9.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200139
#              gene_id:WBGene00000013
#              status:Live
#              sequence_name:C50F2.10
#              gene_name:abf-2
#              other_name:C50F2.e
#              transcript_name:C50F2.10.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200140
#              gene_id:WBGene00000014
#              status:Live
#              sequence_name:F54B8.5
#              gene_name:abf-3
#              other_name:CELE_F54B8.5
#              transcript_name:F54B8.5.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200141
#              gene_id:WBGene00000015
#              status:Live
#              sequence_name:Y38H6C.22
#              gene_name:abf-4
#              other_name:CELE_Y38H6C.22
#              transcript_name:Y38H6C.22.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200142
#              gene_id:WBGene00000016
#              status:Live
#              sequence_name:T22H6.5
#              gene_name:abf-5
#              other_name:CELE_T22H6.5
#              transcript_name:T22H6.5.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200143
#              gene_id:WBGene00000017
#              status:Live
#              sequence_name:T22H6.7
#              gene_name:abf-6
#              other_name:CELE_T22H6.7
#              transcript_name:T22H6.7.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200144
#              gene_id:WBGene00000018
#              status:Live
#              sequence_name:M79.1
#              gene_name:abl-1
#              other_name:CELE_M79.1
#              transcript_name:M79.1a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200145
#              gene_id:WBGene00000018
#              status:Live
#              sequence_name:M79.1
#              gene_name:abl-1
#              other_name:CELE_M79.1
#              transcript_name:M79.1b.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200146
#              gene_id:WBGene00000018
#              status:Live
#              sequence_name:M79.1
#              gene_name:abl-1
#              other_name:CELE_M79.1
#              transcript_name:M79.1c.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200147
#              gene_id:WBGene00000018
#              status:Live
#              sequence_name:M79.1
#              gene_name:abl-1
#              other_name:CELE_M79.1
#              transcript_name:M79.1d.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200148
#              gene_id:WBGene00000018
#              status:Live
#              sequence_name:M79.1
#              gene_name:abl-1
#              other_name:CELE_M79.1
#              transcript_name:M79.1e.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200149
#              gene_id:WBGene00000018
#              status:Live
#              sequence_name:M79.1
#              gene_name:abl-1
#              other_name:CELE_M79.1
#              transcript_name:M79.1f.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200150
#              gene_id:WBGene00000018
#              status:Live
#              sequence_name:M79.1
#              gene_name:abl-1
#              other_name:CELE_M79.1
#              transcript_name:M79.1g.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200151
#              gene_id:WBGene00000018
#              status:Live
#              sequence_name:M79.1
#              gene_name:abl-1
#              other_name:CELE_M79.1
#              transcript_name:M79.1h.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200152
#              gene_id:WBGene00000019
#              status:Live
#              sequence_name:C24F3.5
#              gene_name:abt-1
#              other_name:CELE_C24F3.5
#              transcript_name:C24F3.5a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200153
#              gene_id:WBGene00000019
#              status:Live
#              sequence_name:C24F3.5
#              gene_name:abt-1
#              other_name:CELE_C24F3.5
#              transcript_name:C24F3.5b.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200154
#              gene_id:WBGene00000020
#              status:Live
#              sequence_name:F12B6.1
#              gene_name:abt-2
#              other_name:Y39G10AL.b
#              transcript_name:F12B6.1a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200155
#              gene_id:WBGene00000020
#              status:Live
#              sequence_name:F12B6.1
#              gene_name:abt-2
#              other_name:Y39G10AL.b
#              transcript_name:F12B6.1b.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200156
#              gene_id:WBGene00000021
#              status:Live
#              sequence_name:F55G11.9
#              gene_name:abt-3
#              other_name:CELE_F55G11.9
#              transcript_name:F55G11.9
#              type:pseudogenic_transcripts
#          >,
#  <BigTableV2:
#              id:200157
#              gene_id:WBGene00000022
#              status:Live
#              sequence_name:Y39D8C.1
#              gene_name:abt-4
#              other_name:CELE_Y39D8C.1
#              transcript_name:Y39D8C.1.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200158
#              gene_id:WBGene00000023
#              status:Live
#              sequence_name:Y53C10A.9
#              gene_name:abt-5
#              other_name:CELE_Y53C10A.9
#              transcript_name:Y53C10A.9.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200159
#              gene_id:WBGene00000024
#              status:Live
#              sequence_name:AC3.3
#              gene_name:abu-1
#              other_name:pqn-1
#              transcript_name:AC3.3.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200160
#              gene_id:WBGene00000025
#              status:Live
#              sequence_name:F19G12.7
#              gene_name:abu-2
#              other_name:pqn-30
#              transcript_name:F19G12.7.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200161
#              gene_id:WBGene00000026
#              status:Live
#              sequence_name:F31A3.1
#              gene_name:abu-3
#              other_name:CELE_F31A3.1
#              transcript_name:F31A3.1
#              type:pseudogenic_transcripts
#          >,
#  <BigTableV2:
#              id:200162
#              gene_id:WBGene00000027
#              status:Live
#              sequence_name:Y5H2A.3
#              gene_name:abu-4
#              other_name:Y5H2A.a
#              transcript_name:Y5H2A.3.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200163
#              gene_id:WBGene00000028
#              status:Live
#              sequence_name:Y105C5A.4
#              gene_name:abu-5
#              other_name:pqn-77
#              transcript_name:Y105C5A.4.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200164
#              gene_id:WBGene00000029
#              status:Live
#              sequence_name:C03A7.7
#              gene_name:abu-6
#              other_name:pqn-6
#              transcript_name:C03A7.7.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200165
#              gene_id:WBGene00000030
#              status:Live
#              sequence_name:C03A7.8
#              gene_name:abu-7
#              other_name:pqn-7
#              transcript_name:C03A7.8.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200166
#              gene_id:WBGene00000031
#              status:Live
#              sequence_name:C03A7.14
#              gene_name:abu-8
#              other_name:pqn-4
#              transcript_name:C03A7.14.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200167
#              gene_id:WBGene00000032
#              status:Live
#              sequence_name:R09F10.2
#              gene_name:abu-9
#              other_name:pqn-56
#              transcript_name:R09F10.2.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200168
#              gene_id:WBGene00000033
#              status:Live
#              sequence_name:F35A5.3
#              gene_name:abu-10
#              other_name:pqn-33
#              transcript_name:F35A5.3.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200169
#              gene_id:WBGene00000034
#              status:Live
#              sequence_name:T01D1.6
#              gene_name:abu-11
#              other_name:pqn-61
#              transcript_name:T01D1.6.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200170
#              gene_id:WBGene00000035
#              status:Live
#              sequence_name:W09B12.1
#              gene_name:ace-1
#              other_name:ACE1
#              transcript_name:W09B12.1.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200171
#              gene_id:WBGene00000036
#              status:Live
#              sequence_name:Y44E3A.2
#              gene_name:ace-2
#              other_name:cest-20
#              transcript_name:Y44E3A.2.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200172
#              gene_id:WBGene00000036
#              status:Live
#              sequence_name:Y44E3A.2
#              gene_name:ace-2
#              other_name:cest-20
#              transcript_name:Y44E3A.2.2
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200173
#              gene_id:WBGene00000037
#              status:Live
#              sequence_name:Y48B6A.8
#              gene_name:ace-3
#              other_name:cest-21
#              transcript_name:Y48B6A.8.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200174
#              gene_id:WBGene00000038
#              status:Live
#              sequence_name:Y48B6A.7
#              gene_name:ace-4
#              other_name:cest-22
#              transcript_name:Y48B6A.7.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200175
#              gene_id:WBGene00000039
#              status:Live
#              sequence_name:C42D8.5
#              gene_name:acn-1
#              other_name:CELE_C42D8.5
#              transcript_name:C42D8.5.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200176
#              gene_id:WBGene00000040
#              status:Live
#              sequence_name:ZK455.1
#              gene_name:aco-1
#              other_name:gei-22
#              transcript_name:ZK455.1.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200177
#              gene_id:WBGene00000041
#              status:Live
#              sequence_name:F54H12.1
#              gene_name:aco-2
#              other_name:CELE_F54H12.1
#              transcript_name:F54H12.1a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200178
#              gene_id:WBGene00000041
#              status:Live
#              sequence_name:F54H12.1
#              gene_name:aco-2
#              other_name:CELE_F54H12.1
#              transcript_name:F54H12.1c.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200179
#              gene_id:WBGene00000041
#              status:Live
#              sequence_name:F54H12.1
#              gene_name:aco-2
#              other_name:CELE_F54H12.1
#              transcript_name:F54H12.1c.2
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200180
#              gene_id:WBGene00000041
#              status:Live
#              sequence_name:F54H12.1
#              gene_name:aco-2
#              other_name:CELE_F54H12.1
#              transcript_name:F54H12.1c.3
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200181
#              gene_id:WBGene00000042
#              status:Live
#              sequence_name:K11G12.2
#              gene_name:acr-2
#              other_name:CELE_K11G12.2
#              transcript_name:K11G12.2.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200182
#              gene_id:WBGene00000043
#              status:Live
#              sequence_name:K11G12.7
#              gene_name:acr-3
#              other_name:CELE_K11G12.7
#              transcript_name:K11G12.7.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200183
#              gene_id:WBGene00000044
#              status:Live
#              sequence_name:K03F8.2
#              gene_name:acr-5
#              other_name:CELE_K03F8.2
#              transcript_name:K03F8.2.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200184
#              gene_id:WBGene00000045
#              status:Live
#              sequence_name:ZK973.5
#              gene_name:acr-6
#              other_name:CELE_ZK973.5
#              transcript_name:ZK973.5.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200185
#              gene_id:WBGene00000046
#              status:Live
#              sequence_name:T09A5.3
#              gene_name:acr-7
#              other_name:CELE_T09A5.3
#              transcript_name:T09A5.3.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200186
#              gene_id:WBGene00000047
#              status:Live
#              sequence_name:ZC504.2
#              gene_name:acr-8
#              other_name:CELE_ZC504.2
#              transcript_name:ZC504.2.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200187
#              gene_id:WBGene00000047
#              status:Live
#              sequence_name:ZC504.2
#              gene_name:acr-8
#              other_name:CELE_ZC504.2
#              transcript_name:ZC504.2.2
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200188
#              gene_id:WBGene00000048
#              status:Live
#              sequence_name:C40C9.2
#              gene_name:acr-9
#              other_name:CELE_C40C9.2
#              transcript_name:C40C9.2.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200189
#              gene_id:WBGene00000049
#              status:Live
#              sequence_name:R02E12.8
#              gene_name:acr-10
#              other_name:CELE_R02E12.8
#              transcript_name:R02E12.8.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200190
#              gene_id:WBGene00000050
#              status:Live
#              sequence_name:D2092.3
#              gene_name:acr-11
#              other_name:CELE_D2092.3
#              transcript_name:D2092.3.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200191
#              gene_id:WBGene00000051
#              status:Live
#              sequence_name:R01E6.4
#              gene_name:acr-12
#              other_name:CELE_R01E6.4
#              transcript_name:R01E6.4a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200192
#              gene_id:WBGene00000051
#              status:Live
#              sequence_name:R01E6.4
#              gene_name:acr-12
#              other_name:CELE_R01E6.4
#              transcript_name:R01E6.4b.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200193
#              gene_id:WBGene00000052
#              status:Dead
#              sequence_name:
#              gene_name:
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:200194
#              gene_id:WBGene00000053
#              status:Live
#              sequence_name:T05C12.2
#              gene_name:acr-14
#              other_name:CELE_T05C12.2
#              transcript_name:T05C12.2.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200195
#              gene_id:WBGene00000054
#              status:Live
#              sequence_name:F25G6.4
#              gene_name:acr-15
#              other_name:CELE_F25G6.4
#              transcript_name:F25G6.4.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200196
#              gene_id:WBGene00000055
#              status:Live
#              sequence_name:F25G6.3
#              gene_name:acr-16
#              other_name:Ce21
#              transcript_name:F25G6.3.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200197
#              gene_id:WBGene00000056
#              status:Live
#              sequence_name:F53E10.2
#              gene_name:acr-17
#              other_name:CELE_F53E10.2
#              transcript_name:F53E10.2b.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200198
#              gene_id:WBGene00000056
#              status:Live
#              sequence_name:F53E10.2
#              gene_name:acr-17
#              other_name:CELE_F53E10.2
#              transcript_name:F53E10.2g.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200199
#              gene_id:WBGene00000056
#              status:Live
#              sequence_name:F53E10.2
#              gene_name:acr-17
#              other_name:CELE_F53E10.2
#              transcript_name:F53E10.2h.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200200
#              gene_id:WBGene00000056
#              status:Live
#              sequence_name:F53E10.2
#              gene_name:acr-17
#              other_name:CELE_F53E10.2
#              transcript_name:F53E10.2i.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200201
#              gene_id:WBGene00000056
#              status:Live
#              sequence_name:F53E10.2
#              gene_name:acr-17
#              other_name:CELE_F53E10.2
#              transcript_name:F53E10.2a
#              type:nc_primary_transcript
#          >,
#  <BigTableV2:
#              id:200202
#              gene_id:WBGene00000056
#              status:Live
#              sequence_name:F53E10.2
#              gene_name:acr-17
#              other_name:CELE_F53E10.2
#              transcript_name:F53E10.2c
#              type:nc_primary_transcript
#          >,
#  <BigTableV2:
#              id:200203
#              gene_id:WBGene00000056
#              status:Live
#              sequence_name:F53E10.2
#              gene_name:acr-17
#              other_name:CELE_F53E10.2
#              transcript_name:F53E10.2d
#              type:nc_primary_transcript
#          >,
#  <BigTableV2:
#              id:200204
#              gene_id:WBGene00000056
#              status:Live
#              sequence_name:F53E10.2
#              gene_name:acr-17
#              other_name:CELE_F53E10.2
#              transcript_name:F53E10.2e
#              type:nc_primary_transcript
#          >,
#  <BigTableV2:
#              id:200205
#              gene_id:WBGene00000056
#              status:Live
#              sequence_name:F53E10.2
#              gene_name:acr-17
#              other_name:CELE_F53E10.2
#              transcript_name:F53E10.2f
#              type:nc_primary_transcript
#          >,
#  <BigTableV2:
#              id:200206
#              gene_id:WBGene00000057
#              status:Live
#              sequence_name:F28F8.1
#              gene_name:acr-18
#              other_name:CELE_F28F8.1
#              transcript_name:F28F8.1.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200207
#              gene_id:WBGene00000058
#              status:Live
#              sequence_name:C31H5.3
#              gene_name:acr-19
#              other_name:CELE_C31H5.3
#              transcript_name:C31H5.3a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200208
#              gene_id:WBGene00000058
#              status:Live
#              sequence_name:C31H5.3
#              gene_name:acr-19
#              other_name:CELE_C31H5.3
#              transcript_name:C31H5.3b.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200209
#              gene_id:WBGene00000059
#              status:Live
#              sequence_name:R06A4.10
#              gene_name:acr-20
#              other_name:CELE_R06A4.10
#              transcript_name:R06A4.10a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200210
#              gene_id:WBGene00000059
#              status:Live
#              sequence_name:R06A4.10
#              gene_name:acr-20
#              other_name:CELE_R06A4.10
#              transcript_name:R06A4.10b.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200211
#              gene_id:WBGene00000059
#              status:Live
#              sequence_name:R06A4.10
#              gene_name:acr-20
#              other_name:CELE_R06A4.10
#              transcript_name:R06A4.10c.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200212
#              gene_id:WBGene00000060
#              status:Live
#              sequence_name:F27B3.2
#              gene_name:acr-21
#              other_name:CELE_F27B3.2
#              transcript_name:F27B3.2a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200213
#              gene_id:WBGene00000060
#              status:Live
#              sequence_name:F27B3.2
#              gene_name:acr-21
#              other_name:CELE_F27B3.2
#              transcript_name:F27B3.2b.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200214
#              gene_id:WBGene00000060
#              status:Live
#              sequence_name:F27B3.2
#              gene_name:acr-21
#              other_name:CELE_F27B3.2
#              transcript_name:F27B3.2c.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200215
#              gene_id:WBGene00000060
#              status:Live
#              sequence_name:F27B3.2
#              gene_name:acr-21
#              other_name:CELE_F27B3.2
#              transcript_name:F27B3.2d.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200216
#              gene_id:WBGene00000061
#              status:Live
#              sequence_name:F48E3.7
#              gene_name:lgc-11
#              other_name:acr-22
#              transcript_name:F48E3.7.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200217
#              gene_id:WBGene00000062
#              status:Live
#              sequence_name:F59B1.9
#              gene_name:acr-23
#              other_name:CELE_F59B1.9
#              transcript_name:F59B1.9a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200218
#              gene_id:WBGene00000062
#              status:Live
#              sequence_name:F59B1.9
#              gene_name:acr-23
#              other_name:CELE_F59B1.9
#              transcript_name:F59B1.9b.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200219
#              gene_id:WBGene00000063
#              status:Live
#              sequence_name:T04C12.6
#              gene_name:act-1
#              other_name:CELE_T04C12.6
#              transcript_name:T04C12.6.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200220
#              gene_id:WBGene00000064
#              status:Live
#              sequence_name:T04C12.5
#              gene_name:act-2
#              other_name:act2
#              transcript_name:T04C12.5.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200221
#              gene_id:WBGene00000065
#              status:Live
#              sequence_name:T04C12.4
#              gene_name:act-3
#              other_name:act1
#              transcript_name:T04C12.4.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200222
#              gene_id:WBGene00000065
#              status:Live
#              sequence_name:T04C12.4
#              gene_name:act-3
#              other_name:act1
#              transcript_name:T04C12.4.2
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200223
#              gene_id:WBGene00000065
#              status:Live
#              sequence_name:T04C12.4
#              gene_name:act-3
#              other_name:act1
#              transcript_name:T04C12.4.3
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200224
#              gene_id:WBGene00000066
#              status:Live
#              sequence_name:M03F4.2
#              gene_name:act-4
#              other_name:act4
#              transcript_name:M03F4.2a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200225
#              gene_id:WBGene00000066
#              status:Live
#              sequence_name:M03F4.2
#              gene_name:act-4
#              other_name:act4
#              transcript_name:M03F4.2b.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200226
#              gene_id:WBGene00000067
#              status:Live
#              sequence_name:T25C8.2
#              gene_name:act-5
#              other_name:CELE_T25C8.2
#              transcript_name:T25C8.2.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200227
#              gene_id:WBGene00000068
#              status:Live
#              sequence_name:F17C8.1
#              gene_name:acy-1
#              other_name:sgs-1
#              transcript_name:F17C8.1.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200228
#              gene_id:WBGene00000069
#              status:Live
#              sequence_name:C10F3.3
#              gene_name:acy-2
#              other_name:CELE_C10F3.3
#              transcript_name:C10F3.3.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200229
#              gene_id:WBGene00000070
#              status:Live
#              sequence_name:C44F1.5
#              gene_name:acy-3
#              other_name:CELE_C44F1.5
#              transcript_name:C44F1.5.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200230
#              gene_id:WBGene00000071
#              status:Live
#              sequence_name:T01C2.1
#              gene_name:acy-4
#              other_name:CELE_T01C2.1
#              transcript_name:T01C2.1.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200231
#              gene_id:WBGene00000072
#              status:Live
#              sequence_name:F39C12.2
#              gene_name:add-1
#              other_name:CELE_F39C12.2
#              transcript_name:F39C12.2a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200232
#              gene_id:WBGene00000072
#              status:Live
#              sequence_name:F39C12.2
#              gene_name:add-1
#              other_name:CELE_F39C12.2
#              transcript_name:F39C12.2b.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200233
#              gene_id:WBGene00000072
#              status:Live
#              sequence_name:F39C12.2
#              gene_name:add-1
#              other_name:CELE_F39C12.2
#              transcript_name:F39C12.2c.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200234
#              gene_id:WBGene00000072
#              status:Live
#              sequence_name:F39C12.2
#              gene_name:add-1
#              other_name:CELE_F39C12.2
#              transcript_name:F39C12.2d.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200235
#              gene_id:WBGene00000072
#              status:Live
#              sequence_name:F39C12.2
#              gene_name:add-1
#              other_name:CELE_F39C12.2
#              transcript_name:F39C12.2e.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200236
#              gene_id:WBGene00000073
#              status:Live
#              sequence_name:F57F5.4
#              gene_name:add-2
#              other_name:CELE_F57F5.4
#              transcript_name:F57F5.4a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200237
#              gene_id:WBGene00000073
#              status:Live
#              sequence_name:F57F5.4
#              gene_name:add-2
#              other_name:CELE_F57F5.4
#              transcript_name:F57F5.4b.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200238
#              gene_id:WBGene00000074
#              status:Live
#              sequence_name:C04A11.4
#              gene_name:adm-2
#              other_name:CELE_C04A11.4
#              transcript_name:C04A11.4a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200239
#              gene_id:WBGene00000074
#              status:Live
#              sequence_name:C04A11.4
#              gene_name:adm-2
#              other_name:CELE_C04A11.4
#              transcript_name:C04A11.4b.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200240
#              gene_id:WBGene00000075
#              status:Live
#              sequence_name:ZK154.7
#              gene_name:adm-4
#              other_name:CELE_ZK154.7
#              transcript_name:ZK154.7.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200241
#              gene_id:WBGene00000076
#              status:Live
#              sequence_name:
#              gene_name:adn-1
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:200242
#              gene_id:WBGene00000077
#              status:Live
#              sequence_name:
#              gene_name:adn-2
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:200243
#              gene_id:WBGene00000078
#              status:Live
#              sequence_name:
#              gene_name:adp-1
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:200244
#              gene_id:WBGene00000079
#              status:Live
#              sequence_name:H15N14.1
#              gene_name:adr-1
#              other_name:adr-1c
#              transcript_name:H15N14.1c.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200245
#              gene_id:WBGene00000079
#              status:Live
#              sequence_name:H15N14.1
#              gene_name:adr-1
#              other_name:adr-1c
#              transcript_name:H15N14.1d.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200246
#              gene_id:WBGene00000079
#              status:Live
#              sequence_name:H15N14.1
#              gene_name:adr-1
#              other_name:adr-1c
#              transcript_name:H15N14.1e.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200247
#              gene_id:WBGene00000079
#              status:Live
#              sequence_name:H15N14.1
#              gene_name:adr-1
#              other_name:adr-1c
#              transcript_name:H15N14.1f.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200248
#              gene_id:WBGene00000079
#              status:Live
#              sequence_name:H15N14.1
#              gene_name:adr-1
#              other_name:adr-1c
#              transcript_name:H15N14.1g.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200249
#              gene_id:WBGene00000080
#              status:Live
#              sequence_name:T20H4.4
#              gene_name:adr-2
#              other_name:CELE_T20H4.4
#              transcript_name:T20H4.4.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200250
#              gene_id:WBGene00000081
#              status:Live
#              sequence_name:Y50D7A.7
#              gene_name:ads-1
#              other_name:ADHAPS
#              transcript_name:Y50D7A.7.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200251
#              gene_id:WBGene00000082
#              status:Live
#              sequence_name:C02B4.1
#              gene_name:adt-1
#              other_name:CELE_C02B4.1
#              transcript_name:C02B4.1a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200252
#              gene_id:WBGene00000082
#              status:Live
#              sequence_name:C02B4.1
#              gene_name:adt-1
#              other_name:CELE_C02B4.1
#              transcript_name:C02B4.1b.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200253
#              gene_id:WBGene00000083
#              status:Live
#              sequence_name:F08C6.1
#              gene_name:adt-2
#              other_name:sma-21
#              transcript_name:F08C6.1a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200254
#              gene_id:WBGene00000083
#              status:Live
#              sequence_name:F08C6.1
#              gene_name:adt-2
#              other_name:sma-21
#              transcript_name:F08C6.1b.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200255
#              gene_id:WBGene00000083
#              status:Live
#              sequence_name:F08C6.1
#              gene_name:adt-2
#              other_name:sma-21
#              transcript_name:F08C6.1c.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200256
#              gene_id:WBGene00000084
#              status:Live
#              sequence_name:D2030.10
#              gene_name:aex-1
#              other_name:CELE_D2030.10
#              transcript_name:D2030.10a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200257
#              gene_id:WBGene00000084
#              status:Live
#              sequence_name:D2030.10
#              gene_name:aex-1
#              other_name:CELE_D2030.10
#              transcript_name:D2030.10b.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200258
#              gene_id:WBGene00000085
#              status:Live
#              sequence_name:T14B1.2
#              gene_name:aex-2
#              other_name:CELE_T14B1.2
#              transcript_name:T14B1.2.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200259
#              gene_id:WBGene00000086
#              status:Live
#              sequence_name:C02H7.3
#              gene_name:aex-3
#              other_name:CELE_C02H7.3
#              transcript_name:C02H7.3a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200260
#              gene_id:WBGene00000086
#              status:Live
#              sequence_name:C02H7.3
#              gene_name:aex-3
#              other_name:CELE_C02H7.3
#              transcript_name:C02H7.3b.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200261
#              gene_id:WBGene00000087
#              status:Dead
#              sequence_name:
#              gene_name:
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:200262
#              gene_id:WBGene00000088
#              status:Live
#              sequence_name:F32A7.6
#              gene_name:aex-5
#              other_name:kpc-3
#              transcript_name:F32A7.6.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200263
#              gene_id:WBGene00000089
#              status:Live
#              sequence_name:Y87G2A.4
#              gene_name:aex-6
#              other_name:rab-27
#              transcript_name:Y87G2A.4.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200264
#              gene_id:WBGene00000090
#              status:Live
#              sequence_name:B0334.8
#              gene_name:age-1
#              other_name:daf-23
#              transcript_name:B0334.8a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200265
#              gene_id:WBGene00000090
#              status:Live
#              sequence_name:B0334.8
#              gene_name:age-1
#              other_name:daf-23
#              transcript_name:B0334.8b.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200266
#              gene_id:WBGene00000091
#              status:Live
#              sequence_name:
#              gene_name:age-2
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:200267
#              gene_id:WBGene00000092
#              status:Live
#              sequence_name:F32A6.4
#              gene_name:ags-3
#              other_name:ags-3.1
#              transcript_name:F32A6.4a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200268
#              gene_id:WBGene00000092
#              status:Live
#              sequence_name:F32A6.4
#              gene_name:ags-3
#              other_name:ags-3.1
#              transcript_name:F32A6.4a.2
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200269
#              gene_id:WBGene00000092
#              status:Live
#              sequence_name:F32A6.4
#              gene_name:ags-3
#              other_name:ags-3.1
#              transcript_name:F32A6.4d.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200270
#              gene_id:WBGene00000092
#              status:Live
#              sequence_name:F32A6.4
#              gene_name:ags-3
#              other_name:ags-3.1
#              transcript_name:F32A6.4e.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200271
#              gene_id:WBGene00000092
#              status:Live
#              sequence_name:F32A6.4
#              gene_name:ags-3
#              other_name:ags-3.1
#              transcript_name:F32A6.4f.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200272
#              gene_id:WBGene00000092
#              status:Live
#              sequence_name:F32A6.4
#              gene_name:ags-3
#              other_name:ags-3.1
#              transcript_name:F32A6.4f.2
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200273
#              gene_id:WBGene00000092
#              status:Live
#              sequence_name:F32A6.4
#              gene_name:ags-3
#              other_name:ags-3.1
#              transcript_name:F32A6.4f.3
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200274
#              gene_id:WBGene00000092
#              status:Live
#              sequence_name:F32A6.4
#              gene_name:ags-3
#              other_name:ags-3.1
#              transcript_name:F32A6.4f.4
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200275
#              gene_id:WBGene00000092
#              status:Live
#              sequence_name:F32A6.4
#              gene_name:ags-3
#              other_name:ags-3.1
#              transcript_name:F32A6.4f.5
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200276
#              gene_id:WBGene00000092
#              status:Live
#              sequence_name:F32A6.4
#              gene_name:ags-3
#              other_name:ags-3.1
#              transcript_name:F32A6.4g.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200277
#              gene_id:WBGene00000092
#              status:Live
#              sequence_name:F32A6.4
#              gene_name:ags-3
#              other_name:ags-3.1
#              transcript_name:F32A6.4b
#              type:nc_primary_transcript
#          >,
#  <BigTableV2:
#              id:200278
#              gene_id:WBGene00000092
#              status:Live
#              sequence_name:F32A6.4
#              gene_name:ags-3
#              other_name:ags-3.1
#              transcript_name:F32A6.4c
#              type:nc_primary_transcript
#          >,
#  <BigTableV2:
#              id:200279
#              gene_id:WBGene00000093
#              status:Live
#              sequence_name:Y62E10A.5
#              gene_name:agt-1
#              other_name:cAGT-1
#              transcript_name:Y62E10A.5a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200280
#              gene_id:WBGene00000093
#              status:Live
#              sequence_name:Y62E10A.5
#              gene_name:agt-1
#              other_name:cAGT-1
#              transcript_name:Y62E10A.5b.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200281
#              gene_id:WBGene00000094
#              status:Live
#              sequence_name:F09E5.13
#              gene_name:agt-2
#              other_name:cAGT-2
#              transcript_name:F09E5.13.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200282
#              gene_id:WBGene00000095
#              status:Live
#              sequence_name:C25A1.11
#              gene_name:aha-1
#              other_name:CELE_C25A1.11
#              transcript_name:C25A1.11.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200283
#              gene_id:WBGene00000096
#              status:Live
#              sequence_name:C41G7.5
#              gene_name:ahr-1
#              other_name:CELE_C41G7.5
#              transcript_name:C41G7.5a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200284
#              gene_id:WBGene00000096
#              status:Live
#              sequence_name:C41G7.5
#              gene_name:ahr-1
#              other_name:CELE_C41G7.5
#              transcript_name:C41G7.5b.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200285
#              gene_id:WBGene00000097
#              status:Live
#              sequence_name:F58E10.4
#              gene_name:aip-1
#              other_name:CELE_F58E10.4
#              transcript_name:F58E10.4.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200286
#              gene_id:WBGene00000098
#              status:Live
#              sequence_name:K07C11.2
#              gene_name:air-1
#              other_name:let-412
#              transcript_name:K07C11.2.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200287
#              gene_id:WBGene00000099
#              status:Live
#              sequence_name:B0207.4
#              gene_name:air-2
#              other_name:let-603
#              transcript_name:B0207.4.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:200288
#              gene_id:WBGene00000099
#              status:Live
#              sequence_name:B0207.4
# ...
#              gene_id:WBGene00000567
#              status:Live
#              sequence_name:ZK632.6
#              gene_name:cnx-1
#              other_name:CELE_ZK632.6
#              transcript_name:ZK632.6b.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201061
#              gene_id:WBGene00000568
#              status:Live
#              sequence_name:
#              gene_name:cod-1
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:201062
#              gene_id:WBGene00000569
#              status:Live
#              sequence_name:
#              gene_name:cod-2
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:201063
#              gene_id:WBGene00000570
#              status:Live
#              sequence_name:
#              gene_name:cod-3
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:201064
#              gene_id:WBGene00000571
#              status:Live
#              sequence_name:
#              gene_name:cod-4
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:201065
#              gene_id:WBGene00000572
#              status:Live
#              sequence_name:
#              gene_name:cod-5
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:201066
#              gene_id:WBGene00000573
#              status:Live
#              sequence_name:
#              gene_name:cod-6
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:201067
#              gene_id:WBGene00000574
#              status:Live
#              sequence_name:
#              gene_name:cod-7
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:201068
#              gene_id:WBGene00000575
#              status:Live
#              sequence_name:
#              gene_name:cod-8
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:201069
#              gene_id:WBGene00000576
#              status:Live
#              sequence_name:
#              gene_name:cod-9
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:201070
#              gene_id:WBGene00000577
#              status:Live
#              sequence_name:
#              gene_name:cod-10
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:201071
#              gene_id:WBGene00000578
#              status:Live
#              sequence_name:
#              gene_name:cod-11
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:201072
#              gene_id:WBGene00000579
#              status:Live
#              sequence_name:
#              gene_name:cod-12
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:201073
#              gene_id:WBGene00000580
#              status:Live
#              sequence_name:
#              gene_name:cod-13
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:201074
#              gene_id:WBGene00000581
#              status:Live
#              sequence_name:
#              gene_name:cod-14
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:201075
#              gene_id:WBGene00000582
#              status:Live
#              sequence_name:
#              gene_name:cod-15
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:201076
#              gene_id:WBGene00000583
#              status:Live
#              sequence_name:C48E7.5
#              gene_name:cof-2
#              other_name:col-57
#              transcript_name:C48E7.5.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201077
#              gene_id:WBGene00000584
#              status:Live
#              sequence_name:R03C1.3
#              gene_name:cog-1
#              other_name:CELE_R03C1.3
#              transcript_name:R03C1.3a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201078
#              gene_id:WBGene00000584
#              status:Live
#              sequence_name:R03C1.3
#              gene_name:cog-1
#              other_name:CELE_R03C1.3
#              transcript_name:R03C1.3b.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201079
#              gene_id:WBGene00000585
#              status:Live
#              sequence_name:C06G3.10
#              gene_name:cogc-2
#              other_name:cog2
#              transcript_name:C06G3.10.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201080
#              gene_id:WBGene00000586
#              status:Dead
#              sequence_name:
#              gene_name:
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:201081
#              gene_id:WBGene00000587
#              status:Dead
#              sequence_name:
#              gene_name:
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:201082
#              gene_id:WBGene00000588
#              status:Dead
#              sequence_name:
#              gene_name:
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:201083
#              gene_id:WBGene00000589
#              status:Dead
#              sequence_name:
#              gene_name:
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:201084
#              gene_id:WBGene00000590
#              status:Dead
#              sequence_name:
#              gene_name:
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:201085
#              gene_id:WBGene00000591
#              status:Live
#              sequence_name:K08A8.3
#              gene_name:coh-1
#              other_name:rad-21.2
#              transcript_name:K08A8.3a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201086
#              gene_id:WBGene00000591
#              status:Live
#              sequence_name:K08A8.3
#              gene_name:coh-1
#              other_name:rad-21.2
#              transcript_name:K08A8.3b.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201087
#              gene_id:WBGene00000591
#              status:Live
#              sequence_name:K08A8.3
#              gene_name:coh-1
#              other_name:rad-21.2
#              transcript_name:K08A8.3c.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201088
#              gene_id:WBGene00000591
#              status:Live
#              sequence_name:K08A8.3
#              gene_name:coh-1
#              other_name:rad-21.2
#              transcript_name:K08A8.3d.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201089
#              gene_id:WBGene00000592
#              status:Live
#              sequence_name:F08H9.1
#              gene_name:coh-3
#              other_name:CELE_F08H9.1
#              transcript_name:F08H9.1.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201090
#              gene_id:WBGene00000593
#              status:Live
#              sequence_name:W01B6.7
#              gene_name:col-2
#              other_name:CELE_W01B6.7
#              transcript_name:W01B6.7.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201091
#              gene_id:WBGene00000594
#              status:Live
#              sequence_name:T28C6.6
#              gene_name:col-3
#              other_name:col-117
#              transcript_name:T28C6.6.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201092
#              gene_id:WBGene00000595
#              status:Live
#              sequence_name:
#              gene_name:col-5
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:201093
#              gene_id:WBGene00000596
#              status:Live
#              sequence_name:C15A11.5
#              gene_name:col-7
#              other_name:col7
#              transcript_name:C15A11.5.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201094
#              gene_id:WBGene00000597
#              status:Live
#              sequence_name:F11H8.3
#              gene_name:col-8
#              other_name:col8
#              transcript_name:F11H8.3.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201095
#              gene_id:WBGene00000598
#              status:Live
#              sequence_name:F54B11.1
#              gene_name:col-9
#              other_name:CELE_F54B11.1
#              transcript_name:F54B11.1.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201096
#              gene_id:WBGene00000599
#              status:Live
#              sequence_name:B0222.8
#              gene_name:col-10
#              other_name:CELE_B0222.8
#              transcript_name:B0222.8.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201097
#              gene_id:WBGene00000600
#              status:Live
#              sequence_name:
#              gene_name:col-11
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:201098
#              gene_id:WBGene00000601
#              status:Live
#              sequence_name:F15H10.1
#              gene_name:col-12
#              other_name:CELE_F15H10.1
#              transcript_name:F15H10.1.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201099
#              gene_id:WBGene00000601
#              status:Live
#              sequence_name:F15H10.1
#              gene_name:col-12
#              other_name:CELE_F15H10.1
#              transcript_name:F15H10.1.2
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201100
#              gene_id:WBGene00000601
#              status:Live
#              sequence_name:F15H10.1
#              gene_name:col-12
#              other_name:CELE_F15H10.1
#              transcript_name:F15H10.1.3
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201101
#              gene_id:WBGene00000602
#              status:Live
#              sequence_name:F15H10.2
#              gene_name:col-13
#              other_name:CELE_F15H10.2
#              transcript_name:F15H10.2.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201102
#              gene_id:WBGene00000603
#              status:Live
#              sequence_name:C46A5.3
#              gene_name:col-14
#              other_name:col14
#              transcript_name:C46A5.3a.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201103
#              gene_id:WBGene00000603
#              status:Live
#              sequence_name:C46A5.3
#              gene_name:col-14
#              other_name:col14
#              transcript_name:C46A5.3b.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201104
#              gene_id:WBGene00000604
#              status:Live
#              sequence_name:
#              gene_name:col-15
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:201105
#              gene_id:WBGene00000605
#              status:Live
#              sequence_name:
#              gene_name:col-16
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:201106
#              gene_id:WBGene00000606
#              status:Live
#              sequence_name:F11G11.10
#              gene_name:col-17
#              other_name:CELE_F11G11.10
#              transcript_name:F11G11.10.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201107
#              gene_id:WBGene00000607
#              status:Live
#              sequence_name:
#              gene_name:col-18
#              other_name:
#              transcript_name:
#              type:
#          >,
#  <BigTableV2:
#              id:201108
#              gene_id:WBGene00000608
#              status:Live
#              sequence_name:ZK1193.1
#              gene_name:col-19
#              other_name:col19
#              transcript_name:ZK1193.1.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201109
#              gene_id:WBGene00000609
#              status:Live
#              sequence_name:F11G11.11
#              gene_name:col-20
#              other_name:CELE_F11G11.11
#              transcript_name:F11G11.11.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201110
#              gene_id:WBGene00000610
#              status:Live
#              sequence_name:F36A4.6
#              gene_name:col-33
#              other_name:CELE_F36A4.6
#              transcript_name:F36A4.6.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201111
#              gene_id:WBGene00000611
#              status:Live
#              sequence_name:F36A4.10
#              gene_name:col-34
#              other_name:ram-4
#              transcript_name:F36A4.10.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201112
#              gene_id:WBGene00000612
#              status:Live
#              sequence_name:C15A11.1
#              gene_name:col-35
#              other_name:CELE_C15A11.1
#              transcript_name:C15A11.1.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201113
#              gene_id:WBGene00000613
#              status:Live
#              sequence_name:C27H5.5
#              gene_name:col-36
#              other_name:CELE_C27H5.5
#              transcript_name:C27H5.5.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201114
#              gene_id:WBGene00000614
#              status:Live
#              sequence_name:ZK863.2
#              gene_name:col-37
#              other_name:CELE_ZK863.2
#              transcript_name:ZK863.2.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201115
#              gene_id:WBGene00000615
#              status:Live
#              sequence_name:F54C9.4
#              gene_name:col-38
#              other_name:CELE_F54C9.4
#              transcript_name:F54C9.4.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201116
#              gene_id:WBGene00000616
#              status:Live
#              sequence_name:C09G5.4
#              gene_name:col-39
#              other_name:CELE_C09G5.4
#              transcript_name:C09G5.4.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201117
#              gene_id:WBGene00000617
#              status:Live
#              sequence_name:T13B5.4
#              gene_name:col-40
#              other_name:CELE_T13B5.4
#              transcript_name:T13B5.4.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201118
#              gene_id:WBGene00000618
#              status:Live
#              sequence_name:T10B10.1
#              gene_name:col-41
#              other_name:CELE_T10B10.1
#              transcript_name:T10B10.1.1
#              type:coding_transcript
#          >,
#  <BigTableV2:
#              id:201119
#              gene_id:WBGene00000619
#              status:Dead
#              sequence_name:
#              gene_name:
#              other_name:
#              transcript_name:
#              type:
#          >,
#  ...]
